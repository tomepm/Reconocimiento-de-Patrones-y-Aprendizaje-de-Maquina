# %% [markdown]
# <a href="https://colab.research.google.com/github/tomepm/Reconocimiento-de-Patrones-y-Aprendizaje-de-Maquina/blob/main/TP01_C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Trabajo Práctico N° 1**
# ## **Presentado por:** *Pablo Tomé*
# ## **Enunciado:** Sean cuatro datasets *(conocidos como el cuarteto de Anscombe)*
# ## Supongamos que tenemos cuatro nuevos datos ([16,8]; [8,6]; [16,10] y [16,6]) y sabemos que cada uno corresponde a un único dataset. Sin embargo, los parámetros estadísticos de los cuatro datasets son idénticos. Cómo determinar entonces a qué dataset corresponde cada punto?

# %%
# Importo librerias para trabajar
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Cargo del excel los 4 datasets
FileHoja1 = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/TP01-C.xlsx', sheet_name="Hoja1", header=1)
FileHoja2 = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/TP01-C.xlsx', sheet_name="Hoja2", header=1)
FileHoja3 = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/TP01-C.xlsx', sheet_name="Hoja3", header=1)
FileHoja4 = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/TP01-C.xlsx', sheet_name="Hoja4", header=1)
#FileHoja1.head(11)
#FileHoja2.head(11)
#FileHoja3.head(11)
#FileHoja4.head(11)

# Cargo los dataset en dataframes
DataSet1 = pd.DataFrame(FileHoja1)
DataSet2 = pd.DataFrame(FileHoja2)
DataSet3 = pd.DataFrame(FileHoja3)
DataSet4 = pd.DataFrame(FileHoja4)

# Muestro dataframe del primer dataset a modo de ejemplo para probar código
DataSet1.head(11)
# Out:
#        x      y
# 0   10.0   8.04
# 1    8.0   6.95
# 2   13.0   7.58
# 3    9.0   8.81
# 4   11.0   8.33
# 5   14.0   9.96
# 6    6.0   7.24
# 7    4.0   4.26
# 8   12.0  10.84
# 9    7.0   4.82
# 10   5.0   5.68

# %%
# Cargo el nuevo dataset
newdatas = np.array([[16,8], [8,6], [16,10], [16,6]])

# Transformo el dataset en dataframe y lo muestro
newdatas = pd.DataFrame(newdatas)
newdatas.head()
# Out:
#     0   1
# 0  16   8
# 1   8   6
# 2  16  10
# 3  16   6

# %%
#datos1 = newdatas.to_numpy() # --> Nota personal: Funcion interesante para otros trabajos, transforma un array en dataframe

# Separo los datos nuevos en coordenadas X e Y 
x1 = newdatas[0]
y1 = newdatas[1]

# Grafico de los puntos de los Datasets y de los datos nuevos a evaluar
## Dataset I
plt.scatter(DataSet1['x'],DataSet1['y'], c='blue')    # Grafica puntos de Dataset original
plt.scatter(x1, y1, c='red',  marker='^')             # Grafica puntos de datos nuevos
plt.title('Dataset I')
plt.show()
DataSet1.describe()                                   # Valores estadisticos del Dataset
## Dataset II
plt.scatter(DataSet2['x'],DataSet2['y'], c='blue')    # Grafica puntos de Dataset original
plt.scatter(x1, y1, c='red',  marker='^')             # Grafica puntos de datos nuevos
plt.title('Dataset II')
plt.show()
DataSet2.describe()                                   # Valores estadisticos del Dataset
## Dataset III
plt.scatter(DataSet3['x'],DataSet3['y'], c='blue')    # Grafica puntos de Dataset original
plt.scatter(x1, y1, c='red',  marker='^')             # Grafica puntos de datos nuevos
plt.title('Dataset III')
plt.show()
DataSet3.describe()                                   # Valores estadisticos del Dataset
## Dataset IV
plt.scatter(DataSet4['x'],DataSet4['y'], c='blue')    # Grafica puntos de Dataset original
plt.scatter(x1, y1, c='red',  marker='^')             # Grafica puntos de datos nuevos
plt.title('Dataset IV')
plt.show()
DataSet4.describe()                                   # Valores estadisticos del Dataset
# Out:
#                x          y
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.030579
# min     8.000000   5.250000
# 25%     8.000000   6.170000
# 50%     8.000000   7.040000
# 75%     8.000000   8.190000
# max    19.000000  12.500000
